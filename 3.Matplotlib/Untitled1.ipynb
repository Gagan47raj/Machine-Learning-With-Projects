# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("C:/Users/gagan/Desktop/Python/ML/3.Matplotlib/covid.csv")
ds
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State/UTs        36 non-null     object
#  1   Total Cases      36 non-null     int64
#  2   Active           36 non-null     int64
#  3   Discharged       36 non-null     int64
#  4   Deaths           36 non-null     int64
#  5   Active Ratio     36 non-null     float64
#  6   Discharge Ratio  36 non-null     float64
#  7   Death Ratio      36 non-null     float64
#  8   Population       36 non-null     int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 2.7+ KB

# %%
ds1 = ds[['State/UTs','Total Cases']]

# %%
ds1
# Out:
#                                    State/UTs  Total Cases
# 0                        Andaman and Nicobar        10766
# 1                             Andhra Pradesh      2340676
# 2                          Arunachal Pradesh        67049
# 3                                      Assam       746159
# 4                                      Bihar       855267
# 5                                 Chandigarh       100693
# 6                               Chhattisgarh      1187695
# 7   Dadra and Nagar Haveli and Daman and Diu        11592
# 8                                      Delhi      2040910
# 9                                        Goa       263346
# 10                                   Gujarat      1291383
# 11                                   Haryana      1078903
# 12                          Himachal Pradesh       322905
# 13                         Jammu and Kashmir       482023
# 14                                 Jharkhand       443826
# ...

# %%
ds1.set_index('State/UTs', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45124\3939139354.py in ?()
# ----> 1 ds1 = ds1.set_index('State/UTs', inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['State/UTs'] are in the columns"

# %%
ds1
# Out:
#                                           Total Cases
# State/UTs
# Andaman and Nicobar                             10766
# Andhra Pradesh                                2340676
# Arunachal Pradesh                               67049
# Assam                                          746159
# Bihar                                          855267
# Chandigarh                                     100693
# Chhattisgarh                                  1187695
# Dadra and Nagar Haveli and Daman and Diu        11592
# Delhi                                         2040910
# Goa                                            263346
# Gujarat                                       1291383
# Haryana                                       1078903
# Himachal Pradesh                               322905
# Jammu and Kashmir                              482023
# Jharkhand                                      443826
# Karnataka                                     4088769
# ...

# %%
plt.bar(ds1.index, ds1['Total Cases'])
plt.xlabel("State/UTs")
plt.ylabel("Total Cases")
plt.xticks(rotation = 90)
plt.title("Total covid cases in india state wise")
plt.show()
